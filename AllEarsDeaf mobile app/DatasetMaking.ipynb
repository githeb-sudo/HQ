# %%
import os
import string 
import shutil

# %%
path=r"C:\Users\Dell\Desktop\zzzzz\projet tutoré\interpetation using python\asl_alphabet_train1111111\asl_alphabet_train"
#path2="c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslimage"
path2="c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet"

# %%
def fun(p):
    files=[];
    for r,d,f in os.walk(p):
        for file in f:
            files.append(os.path.join(r,file))
    return files
files1=fun(path)
files2=fun(path2)

# %% [markdown]
# for f in files1:
#     print(f)

# %%
print(len(files1))
# Out:
# 87000

# %%
files1[1]
# Out:
# 'C:\\Users\\Dell\\Desktop\\zzzzz\\projet tutoré\\interpetation using python\\asl_alphabet_train1111111\\asl_alphabet_train\\A\\A10.jpg'

# %% [markdown]
# print(type(f[0]))

# %%
def fun1(files,text):
    l=[];
    sub="";
    for i in files:
        j=i.find(text)+len(text)+3;
        sub=i[j:j+1];
        l.append(sub);
    return l

# %% [markdown]
# l1=fun1(files1,"aslalphabet");
# for i in l1:
#     print(i)

# %%
for i in range(27):
    path=""
    path="c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/dataset/"+chr(65+i)
    os.makedirs(path)

# %%
def fun2(files,text):
    for i in files:
            j=i[i.rfind(text)+len(text)+3];
            print(i)
            print(j)
            path="c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/dataset/"+j
            shutil.copy(i, path)
fun2(files1,"aslimage")
fun2(files2,"aslalphabet")
# Out:
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0001_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0002_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0003_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0004_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0005_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0006_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0007_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0008_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0009_test.jpg
# A
# c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/aslalphabet\A\A0010_test.jpg
# A
# ...

# %%
def fun2(files,text):
    for i in range(0,87000,10):
        k=files[i]
        j=k[k.rfind(text)+len(text)+3];
        print(i)
        print(j)
        path="c://Users/Dell/Desktop/zzzzz/projet tutoré/dataset making/dataset/"+j
        shutil.copy(k, path)
fun2(files1,"asl_alphabet_train")
